# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/Colab Notebooks/pml_pl_defect')

# !pwd
# Out:
# /content/drive/MyDrive/Colab Notebooks/pml_pl_defect

# %%
# !pip install -q timm wandb pytorch-metric-learning[with-hooks] torchmetrics pytorch-lightning
# !pip install -q hydra-core --upgrade
# Out:
#      |████████████████████████████████| 549 kB 15.9 MB/s
#      |████████████████████████████████| 1.9 MB 91.4 MB/s
#      |████████████████████████████████| 111 kB 94.2 MB/s
#      |████████████████████████████████| 512 kB 96.8 MB/s
#      |████████████████████████████████| 800 kB 72.6 MB/s
#      |████████████████████████████████| 182 kB 81.0 MB/s
#      |████████████████████████████████| 182 kB 71.9 MB/s
#      |████████████████████████████████| 174 kB 89.1 MB/s
#      |████████████████████████████████| 62 kB 1.6 MB/s
#      |████████████████████████████████| 173 kB 93.6 MB/s
#      |████████████████████████████████| 168 kB 75.1 MB/s
#      |████████████████████████████████| 168 kB 104.0 MB/s
#      |████████████████████████████████| 166 kB 81.1 MB/s
#      |████████████████████████████████| 166 kB 87.6 MB/s
#      |████████████████████████████████| 162 kB 110.2 MB/s
#      |████████████████████████████████| 162 kB 94.2 MB/s
#      |████████████████████████████████| 158 kB 93.5 MB/s
#      |████████████████████████████████| 157 kB 76.6 MB/s
#      |████████████████████████████████| 157 kB 79.8 MB/s
#      |████████████████████████████████| 157 kB 96.3 MB/s
#      |████████████████████████████████| 157 kB 109.2 MB/s
#      |████████████████████████████████| 157 kB 75.8 MB/s
#      |████████████████████████████████| 157 kB 98.2 MB/s
#      |████████████████████████████████| 157 kB 50.0 MB/s
#      |████████████████████████████████| 156 kB 65.5 MB/s
#      |████████████████████████████████| 125 kB 107.2 MB/s
#      |████████████████████████████████| 85.5 MB 88.6 MB/s
#   Building wheel for pathtools (setup.py) ... done
#      |████████████████████████████████| 154 kB 13.8 MB/s
#      |████████████████████████████████| 117 kB 89.3 MB/s
#      |████████████████████████████████| 79 kB 170 kB/s
#   Building wheel for antlr4-python3-runtime (setup.py) ... done

# %%
# !wandb login
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !python inference.py --timm_name convnext_base \
                     --model_name divine-gorge-3 \
                     --wandb_run_path insilicomab/pml-pl-defect/3jd7uu80 \
                     --image_size 224 \
                     --embedding_size 512 \
                     --k 10
# Out:
# odict_keys(['model.trunk.stem.0.weight', 'model.trunk.stem.0.bias', 'model.trunk.stem.1.weight', 'model.trunk.stem.1.bias', 'model.trunk.stages.0.blocks.0.gamma', 'model.trunk.stages.0.blocks.0.conv_dw.weight', 'model.trunk.stages.0.blocks.0.conv_dw.bias', 'model.trunk.stages.0.blocks.0.norm.weight', 'model.trunk.stages.0.blocks.0.norm.bias', 'model.trunk.stages.0.blocks.0.mlp.fc1.weight', 'model.trunk.stages.0.blocks.0.mlp.fc1.bias', 'model.trunk.stages.0.blocks.0.mlp.fc2.weight', 'model.trunk.stages.0.blocks.0.mlp.fc2.bias', 'model.trunk.stages.0.blocks.1.gamma', 'model.trunk.stages.0.blocks.1.conv_dw.weight', 'model.trunk.stages.0.blocks.1.conv_dw.bias', 'model.trunk.stages.0.blocks.1.norm.weight', 'model.trunk.stages.0.blocks.1.norm.bias', 'model.trunk.stages.0.blocks.1.mlp.fc1.weight', 'model.trunk.stages.0.blocks.1.mlp.fc1.bias', 'model.trunk.stages.0.blocks.1.mlp.fc2.weight', 'model.trunk.stages.0.blocks.1.mlp.fc2.bias', 'model.trunk.stages.0.blocks.2.gamma', 'model.trunk.stages.0.blocks.2.conv_dw.weight', 'model.trunk.stages.0.blocks.2.conv_dw.bias', 'model.trunk.stages.0.blocks.2.norm.weight', 'model.trunk.stages.0.blocks.2.norm.bias', 'model.trunk.stages.0.blocks.2.mlp.fc1.weight', 'model.trunk.stages.0.blocks.2.mlp.fc1.bias', 'model.trunk.stages.0.blocks.2.mlp.fc2.weight', 'model.trunk.stages.0.blocks.2.mlp.fc2.bias', 'model.trunk.stages.1.downsample.0.weight', 'model.trunk.stages.1.downsample.0.bias', 'model.trunk.stages.1.downsample.1.weight', 'model.trunk.stages.1.downsample.1.bias', 'model.trunk.stages.1.blocks.0.gamma', 'model.trunk.stages.1.blocks.0.conv_dw.weight', 'model.trunk.stages.1.blocks.0.conv_dw.bias', 'model.trunk.stages.1.blocks.0.norm.weight', 'model.trunk.stages.1.blocks.0.norm.bias', 'model.trunk.stages.1.blocks.0.mlp.fc1.weight', 'model.trunk.stages.1.blocks.0.mlp.fc1.bias', 'model.trunk.stages.1.blocks.0.mlp.fc2.weight', 'model.trunk.stages.1.blocks.0.mlp.fc2.bias', 'model.trunk.stages.1.blocks.1.gamma', 'model.trunk.stages.1.blocks.1.conv_dw.weight', 'model.trunk.stages.1.blocks.1.conv_dw.bias', 'model.trunk.stages.1.blocks.1.norm.weight', 'model.trunk.stages.1.blocks.1.norm.bias', 'model.trunk.stages.1.blocks.1.mlp.fc1.weight', 'model.trunk.stages.1.blocks.1.mlp.fc1.bias', 'model.trunk.stages.1.blocks.1.mlp.fc2.weight', 'model.trunk.stages.1.blocks.1.mlp.fc2.bias', 'model.trunk.stages.1.blocks.2.gamma', 'model.trunk.stages.1.blocks.2.conv_dw.weight', 'model.trunk.stages.1.blocks.2.conv_dw.bias', 'model.trunk.stages.1.blocks.2.norm.weight', 'model.trunk.stages.1.blocks.2.norm.bias', 'model.trunk.stages.1.blocks.2.mlp.fc1.weight', 'model.trunk.stages.1.blocks.2.mlp.fc1.bias', 'model.trunk.stages.1.blocks.2.mlp.fc2.weight', 'model.trunk.stages.1.blocks.2.mlp.fc2.bias', 'model.trunk.stages.2.downsample.0.weight', 'model.trunk.stages.2.downsample.0.bias', 'model.trunk.stages.2.downsample.1.weight', 'model.trunk.stages.2.downsample.1.bias', 'model.trunk.stages.2.blocks.0.gamma', 'model.trunk.stages.2.blocks.0.conv_dw.weight', 'model.trunk.stages.2.blocks.0.conv_dw.bias', 'model.trunk.stages.2.blocks.0.norm.weight', 'model.trunk.stages.2.blocks.0.norm.bias', 'model.trunk.stages.2.blocks.0.mlp.fc1.weight', 'model.trunk.stages.2.blocks.0.mlp.fc1.bias', 'model.trunk.stages.2.blocks.0.mlp.fc2.weight', 'model.trunk.stages.2.blocks.0.mlp.fc2.bias', 'model.trunk.stages.2.blocks.1.gamma', 'model.trunk.stages.2.blocks.1.conv_dw.weight', 'model.trunk.stages.2.blocks.1.conv_dw.bias', 'model.trunk.stages.2.blocks.1.norm.weight', 'model.trunk.stages.2.blocks.1.norm.bias', 'model.trunk.stages.2.blocks.1.mlp.fc1.weight', 'model.trunk.stages.2.blocks.1.mlp.fc1.bias', 'model.trunk.stages.2.blocks.1.mlp.fc2.weight', 'model.trunk.stages.2.blocks.1.mlp.fc2.bias', 'model.trunk.stages.2.blocks.2.gamma', 'model.trunk.stages.2.blocks.2.conv_dw.weight', 'model.trunk.stages.2.blocks.2.conv_dw.bias', 'model.trunk.stages.2.blocks.2.norm.weight', 'model.trunk.stages.2.blocks.2.norm.bias', 'model.trunk.stages.2.blocks.2.mlp.fc1. ...
# 100% 100/100 [01:12<00:00,  1.39it/s]
